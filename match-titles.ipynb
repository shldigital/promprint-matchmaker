# %%
from pathlib import Path
from src.matchmaker.titles_match import main

# %%
debug = False
register = Path("/home/nic/dev/promprint-data/2026-06-16-datawrangling-v1.5.1-clean_register-1863b/251104-1863b-full_export.csv")
collection = Path("/home/nic/dev/promprint-data/2026-06-16-datawrangling-v1.5.1-nls-catalog/nls_catalog_1863b_export.tsv")
outpath = Path("../promprint-data/2026-06-30-matchmaker-v0.6.2-titles-match-null-and-creator-guess/")
score_threshold = 69
word_threshold = 2
processes = 6
publishers_index = Path("../promprint-data/2026-05-19-mm-v0.5.6-publishers-index-n-grams/publisher_index.csv")
n_gram_index = Path("../promprint-data/2026-03-30-matchmaker-0.4.0-n-grams/n_gram_top_ordered.csv")

main(debug, register, collection, outpath, score_threshold, word_threshold, processes, publishers_index, n_gram_index)
# Out:
# No. of matched entries: 7466
# No. of unmatched entries: 1193 / 8659
