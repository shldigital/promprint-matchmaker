# %%
from pathlib import Path
from src.matchmaker.titles_match import main

# %%
debug = False
register = Path("../promprint-data/2026-02-18-data-wrangling-v1.2.0-1863/251104-1863b-full_export.csv")
collection = Path("../promprint-data/2026-03-30-data-wrangling-v1.4.0-nls-catalog-deduplicate/nls_catalog_1863b_export.tsv")
outpath = Path("../promprint-data/2026-06-16-matchmaker-v5.7.0-titles-match/")
score_threshold = 79
word_threshold = 2
processes = 6
publishers_index = Path("../promprint-data/2026-05-19-mm-v0.5.6-publishers-index-n-grams/publisher_index.csv")
n_gram_index = Path("../promprint-data/2026-03-30-matchmaker-0.4.0-n-grams/n_gram_top_ordered.csv")

main(debug, register, collection, outpath, score_threshold, word_threshold, processes, publishers_index, n_gram_index)
# Out:
# No. of matched entries: 4136
# No. of unmatched entries: 4523 / 8659
